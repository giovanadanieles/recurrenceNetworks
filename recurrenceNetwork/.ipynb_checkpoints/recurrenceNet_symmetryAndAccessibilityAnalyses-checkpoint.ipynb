# %% [markdown]
# # Recurrence networks (analyzing accessibility and symmetry)

# %%
### command to show execution time
# %load_ext autotime
# Out:
# time: 0 ns

# %% [markdown]
# ## Text processing

# %% [markdown]
# ### Gutenberg project

# %%
### retrieve gutenberg book 

from gutenberg.query import get_metadata
from gutenberg.acquire import load_etext
from gutenberg.cleanup import strip_headers

def retrieve_text(index):
    try:
        text = strip_headers(load_etext(index)).strip()
    except:
        text = ""
    return text

def retrieve_author(index):
    return list(get_metadata('author', index))[0]

def retrieve_title(index):
    return list(get_metadata('title', index))

def retrieve_languages(index):
    return list(get_metadata('language', index))

def retrieve_subjects(index):
    return list(get_metadata('subject', index))
# Out:
# time: 47 ms

# %% [markdown]
# ## Retrieving all networks

# %%
### retrieve all networks from 'pca 300 networks' folder and store it in an array 

import os
import pickle

def getNetworks(window):

    networks = []
    path = './pca 300 networks new right/'
    directory = os.fsencode(path)

    for file in os.listdir(directory):
        filename = path + os.fsdecode(file)
        if filename.endswith(str(window)+".p"):
            f = open(filename, 'rb')
            G = pickle.load(f)
            f.close()

            # getting gutenberg_id and saving on graph
            start = len(path) + len('network_')
            end = len('_w'+ str(window) + '.p')
            gutenberg_id = filename[start:-end]
            
            G['gutenberg_id'] = gutenberg_id
            networks.append(G)
            
    return networks
# Out:
# time: 15 ms

# %%
### filter edges of the networks in the array based on fixed avg degree

def filterNetworkEdges(networks, avg_degree):
    filteredNetworks = []
    for G in networks:
        # filtering edges based on the avg degree that we want
        weights = sorted(G.es['weight'], reverse=True)
        newECount = avg_degree * G.vcount() // 2
        minWeight = weights[min(newECount, len(weights)-1)]
        G.es.select(weight_lt=minWeight).delete()
        filteredNetworks.append(G)
    return filteredNetworks
# Out:
# time: 0 ns

# %% [markdown]
# ## Joining with side project: extracting communities from subjects network

# %%
from collections import Counter

def format_subject(subject):
    return ''.join(c for c in subject if c.lower() in 'abcdefghijklmnopqrstuvwxyz1234567890 -')

def get_book_community(book_id):
    subjects = [format_subject(subj) for subj in retrieve_subjects(book_id)]
    targets = [dic_subj_comm[subj] for subj in subjects]

    return 'fiction' if Counter(targets).most_common(1)[0][0] <= 1 else 'others'
#     return 'fiction' if Counter(targets).most_common(1)[0][0] == 0 else 'juvenile fiction' if Counter(targets).most_common(1)[0][0] == 1 else 'others'

# %%
import xnetwork as xn
from igraph import *
import matplotlib.pyplot as plt

G = xn.xnet2igraph('projection_onto_genres.xnet')

dic_subj_comm = {}

N_COMM = 2
for v in G.vs:
    dic_subj_comm[v['name']] = int(v['Community']) if int(v['Community']) < N_COMM else N_COMM

dic_comm_subj = {}
for k, v in dic_subj_comm.items():
    if v in dic_comm_subj:
        dic_comm_subj[v].append(k)
    else:
        dic_comm_subj[v] = [k]

# %%
dic_subj_comm
# Out:
# {'United States -- History -- Revolution 1775-1783 -- Sources': 2,
#  'JK': 2,
#  'United States Declaration of Independence': 2,
#  'E201': 2,
#  'Civil rights -- United States -- Sources': 2,
#  'KF': 2,
#  'United States Constitution 1st-10th Amendments': 2,
#  'Presidents -- United States -- Inaugural addresses': 2,
#  'E838': 2,
#  'United States -- Foreign relations -- 1961-1963': 2,
#  'E456': 2,
#  'Soldiers National Cemetery Gettysburg Pa': 2,
#  'Lincoln Abraham 1809-1865 Gettysburg address': 2,
#  'Consecration of cemeteries -- Pennsylvania -- Gettysburg': 2,
#  'United States Constitution': 2,
#  'United States -- Politics and government -- 1783-1789 -- Sources': 2,
#  'Virginia -- Politics and government -- 1775-1783 -- Sources': 2,
#  'Speeches addresses etc American': 2,
#  'United States -- Politics and government -- 1775-1783 -- Sources': 2,
#  'Pilgrims New Plymouth Colony': 2,
#  'Massachusetts -- History -- New Plymouth 1620-1691 -- Sources': 2,
#  'F001': 2,
#  'Mayflower Compact 1620': 2,
#  'United States -- Politics and government -- 1861-1865': 2,
#  'BS': 2,
#  'Bible': 2,
#  'Imaginary places -- Juvenile fiction': 1,
#  'PR': 0,
#  'Fantasy fiction': 1,
#  'Childrens stories': 1,
#  'Alice Fictitious character from Carroll -- Juvenile fiction': 1,
#  'PZ': 1,
#  'Nonsense verses English': 2,
#  'Geography -- Handbooks manuals etc': 2,
#  'Political statistics -- Handbooks manuals etc': 2,
#  'World politics -- Handbooks manuals etc': 2,
#  'Political science -- Handbooks manuals etc': 2,
#  'G': 2,
#  'PS': 0,
#  'Whaling -- Fiction': 0,
#  'Mentally ill -- Fiction': 0,
#  'Psychological fiction': 0,
#  'Ship captains -- Fiction': 0,
#  'Whales -- Fiction': 0,
#  'Whaling ships -- Fiction': 0,
#  'Ahab Captain Fictitious character -- Fiction': 0,
#  'Sea stories': 0,
#  'Adventure stories': 1,
#  'Peter Pan Fictitious character -- Fiction': 1,
#  'Never-Never Land Imaginary place -- Fiction': 1,
#  'Pirates -- Fiction': 0,
#  'Fantasy literature': 1,
#  'Fairies -- Fiction': 0,
#  'BX': 2,
#  'Church of Jesus Christ of Latter-day Saints -- Sacred books': 2,
#  'Mormon Church -- Sacred books': 2,
#  'Constitutional law -- United States': 2,
#  'Constitutional history -- United States -- Sources': 2,
#  'Iroquois Indians -- Kings and rulers -- Poetry': 2,
#  'Indians of North America -- Poetry': 2,
#  'Hiawatha active 15th century -- Poetry': 2,
#  'Fall of man -- Poetry': 2,
#  'Adam Biblical figure -- Poetry': 2,
#  'Bible Genesis -- History of Biblical events -- Poetry': 2,
#  'Eve Biblical figure -- Poetry': 2,
#  'PA': 2,
#  'Fables Greek -- Translations into English': 2,
#  'Aesops fables -- Translations into English': 2,
#  'English language -- Synonyms and antonyms': 2,
#  'PE': 2,
#  'Abolitionists -- United States -- Biography': 2,
#  'Slaves -- United States -- Biography': 2,
#  'E300': 2,
#  'Douglass Frederick 1818-1895': 2,
#  'African American abolitionists -- Biography': 2,
#  'Swedish Americans -- Fiction': 0,
#  'Nebraska -- Fiction': 0,
#  'Women pioneers -- Fiction': 0,
#  'Women immigrants -- Fiction': 0,
#  'Brothers and sisters -- Fiction': 0,
#  'Women farmers -- Fiction': 0,
#  'Historical fiction': 0,
#  'Farm life -- Fiction': 0,
#  'Domestic fiction': 0,
#  'Frontier and pioneer life -- Nebraska -- Fiction': 0,
#  'Love stories': 0,
#  'Wessex England -- Fiction': 0,
#  'Triangles Interpersonal relations -- Fiction': 0,
#  'Didactic fiction': 0,
#  'Pastoral fiction': 0,
#  'United States -- Census': 2,
#  'United States -- Population -- Statistics': 2,
#  'Housing -- United States -- Statistics': 2,
#  'HA': 2,
#  'Oedipus Greek mythological figure -- Drama': 2,
#  'Antigone Mythological character -- Drama': 2,
#  'Tragedies': 2,
#  'Greek drama Tragedy -- Translations into English': 2,
#  'Black humor': 0,
#  'Women -- Fiction': 0,
#  'Utopian fiction': 0,
#  'Utopias -- Fiction': 0,
#  'Clergy -- Fiction': 0,
#  'Illegitimate children -- Fiction': 0,
#  'Puritans -- Fiction': 0,
#  'Revenge -- Fiction': 0,
#  'Adultery -- Fiction': 0,
#  'Married women -- Fiction': 0,
#  'Boston Mass -- History -- Colonial period ca 1600-1775 -- Fiction': 0,
#  'TK': 2,
#  'Internet': 2,
#  'Information retrieval': 2,
#  'Information networks': 2,
#  'Computer networks': 2,
#  'Science fiction': 0,
#  'Time travel -- Fiction': 0,
#  'Dystopias -- Fiction': 0,
#  'Martians -- Fiction': 0,
#  'Imaginary wars and battles -- Fiction': 0,
#  'Mars Planet -- Fiction': 0,
#  'Space warfare -- Fiction': 0,
#  'War stories': 0,
#  'Life on other planets -- Fiction': 0,
#  'Computers -- Slang -- Dictionaries': 2,
#  'Computers -- Humor': 2,
#  'Electronic data processing -- Terminology -- Humor': 2,
#  'New York State -- History -- 1775-1865 -- Fiction': 0,
#  'Ghosts -- Fiction': 0,
#  'Physicians -- Fiction': 0,
#  'Multiple personality -- Fiction': 0,
#  'Horror tales': 0,
#  'Self-experimentation in medicine -- Fiction': 0,
#  'London England -- Fiction': 0,
#  'Opera -- Fiction': 0,
#  'Colorado -- Fiction': 0,
#  'Women singers -- Fiction': 0,
#  'Bildungsromans': 0,
#  'Chicago Ill -- Fiction': 0,
#  'Children of clergy -- Fiction': 0,
#  'Young women -- Fiction': 0,
#  'Musical fiction': 0,
#  'Shirley Anne Fictitious character -- Fiction': 0,
#  'Friendship -- Fiction': 0,
#  'Orphans -- Fiction': 0,
#  'Prince Edward Island -- History -- 20th century -- Fiction': 0,
#  'Girls -- Fiction': 0,
#  'Country life -- Prince Edward Island -- Fiction': 0,
#  'Canada -- History -- 1867-1914 -- Fiction': 0,
#  'Islands -- Fiction': 0,
#  'Misers -- Fiction': 0,
#  'Sick children -- Fiction': 0,
#  'Poor families -- Fiction': 0,
#  'Ghost stories': 0,
#  'Scrooge Ebenezer Fictitious character -- Fiction': 0,
#  'Christmas stories': 1,
#  'Teachers -- Fiction': 0,
#  'Canada -- History -- 1914-1945 -- Fiction': 0,
#  'Internet addresses -- Directories': 2,
#  'Computer network resources -- Directories': 2,
#  'Electronic mail systems -- Directories': 2,
#  'Mathematics': 2,
#  'Pi': 2,
#  'QA': 2,
#  'Universities and colleges -- Fiction': 0,
#  'Interpersonal relations -- Fiction': 0,
#  'Nova Scotia -- History -- 20th century -- Fiction': 0,
#  'Self-perception -- Fiction': 0,
#  'Square root': 2,
#  'Z': 2,
#  'Electronic books': 2,
#  'Electronic publishing -- Congresses': 2,
#  'Text processing Computer science -- Congresses': 2,
#  'Friendship -- Juvenile fiction': 1,
#  'Witches -- Juvenile fiction': 1,
#  'Practical jokes -- Juvenile fiction': 1,
#  'Youth -- Conduct of life -- Juvenile fiction': 1,
#  'Kings and rulers -- Juvenile fiction': 1,
#  'Women soldiers -- Juvenile fiction': 1,
#  'Queens -- Juvenile fiction': 1,
#  'Conduct of life -- Juvenile fiction': 1,
#  'Oz Imaginary place -- Juvenile fiction': 1,
#  'Magic -- Juvenile fiction': 1,
#  'Voyages and travels -- Juvenile fiction': 1,
#  'Gale Dorothy Fictitious character -- Juvenile fiction': 1,
#  'Home -- Juvenile fiction': 1,
#  'Courage -- Juvenile fiction': 1,
#  'Cowardly Lion Fictitious character -- Juvenile fiction': 1,
#  'Toto Fictitious character -- Juvenile fiction': 1,
#  'Dreams -- Juvenile fiction': 1,
#  'Wizard of Oz Fictitious character -- Juvenile fiction': 1,
#  'Cyclones -- Juvenile fiction': 1,
#  'Scarecrow Fictitious character from Baum -- Juvenile fiction': 1,
#  'Good and evil -- Juvenile fiction': 1,
#  'Tin Woodman Fictitious character -- Juvenile fiction': 1,
#  'National Research and Education Network Computer network': 2,
#  'Arabs -- Folklore': 0,
#  'Folklore -- Arab countries': 1,
#  'Fairy tales': 1,
#  'Bible Gospels -- History of Biblical events -- Poetry': 2,
#  'Epic poetry': 2,
#  'English poetry': 2,
#  'Jesus Christ -- Temptation -- Poetry': 2,
#  'B': 2,
#  'Methodology': 2,
#  'Science -- Methodology': 2,
#  'British -- France -- Fiction': 0,
#  'France -- History -- Revolution 1789-1799 -- Fiction': 0,
#  'Blakeney Percy Sir Fictitious character -- Fiction': 0,
#  'Nobility -- Fiction': 0,
#  'HX': 2,
#  'Communism': 2,
#  'Socialism': 2,
#  'Princesses -- Fiction': 0,
#  'Dejah Thoris Fictitious character -- Fiction': 0,
#  'Carter John Fictitious character -- Fiction': 0,
#  'Mathematical constants': 2,
#  'Numbers Prime': 2,
#  'Radio broadcasting': 2,
#  'Slavery -- United States -- History': 2,
#  'E151': 2,
#  'African Americans -- History': 2,
#  'Number theory': 2,
#  'American essays': 2,
#  'Government Resistance to': 2,
#  'Civil disobedience': 2,
#  'HM': 2,
#  'United States -- History -- Civil War 1861-1865 -- Fiction': 0,
#  'Chancellorsville Battle of Chancellorsville Va 1863 -- Fiction': 0,
#  'Virginia -- History -- Civil War 1861-1865 -- Fiction': 0,
#  'Humorous stories': 0,
#  'Sawyer Tom Fictitious character -- Fiction': 0,
#  'Child witnesses -- Fiction': 0,
#  'Mississippi River Valley -- Fiction': 0,
#  'Boys -- Fiction': 0,
#  'Male friendship -- Fiction': 0,
#  'Runaway children -- Fiction': 0,
#  'Missouri -- Fiction': 0,
#  'Electronic mail systems': 2,
#  'Fugitive slaves -- Fiction': 0,
#  'Mississippi River -- Fiction': 0,
#  'Race relations -- Fiction': 0,
#  'Finn Huckleberry Fictitious character -- Fiction': 0,
#  'Paranormal fiction': 0,
#  'Haunted houses -- Fiction': 0,
#  'Salem Mass -- Fiction': 0,
#  'Tarzan Fictitious character -- Fiction': 0,
#  'Wild men -- Fiction': 0,
#  'British -- Africa -- Fiction': 0,
#  'Africa -- Fiction': 0,
#  'Computer security -- Fiction': 0,
#  'Privacy Right of -- Fiction': 0,
#  'PQ': 0,
#  'Records -- Access control -- Fiction': 0,
#  'Ivanhoe Wilfred of Sir Fictitious character -- Fiction': 0,
#  'Normans -- Great Britain -- Fiction': 0,
#  'Anglo-Saxons -- Fiction': 0,
#  'Jews -- England -- Fiction': 0,
#  'Knights and knighthood -- Fiction': 0,
#  'Great Britain -- History -- Richard I 1189-1199 -- Fiction': 0,
#  'Moon -- Fiction': 0,
#  'Space ships -- Fiction': 0,
#  'Space flight to the moon -- Fiction': 0,
#  'Manned space flight -- Fiction': 0,
#  'Frankensteins monster Fictitious character -- Fiction': 0,
#  'Monsters -- Fiction': 0,
#  'Scientists -- Fiction': 0,
#  'Gothic fiction': 0,
#  'Frankenstein Victor Fictitious character -- Fiction': 0,
#  'Jungle animals -- Fiction': 0,
#  'Britons -- Fiction': 0,
#  'Americans -- Great Britain -- Fiction': 0,
#  'Kings and rulers -- Fiction': 0,
#  'Satire': 0,
#  'Arthurian romances -- Adaptations': 2,
#  'HG': 2,
#  'Cost and standard of living': 2,
#  'Foreign trade regulation -- North America': 2,
#  'KDZ': 2,
#  'Tariff -- Law and legislation -- North America': 2,
#  'Free trade -- United States': 2,
#  'Canada Treaties etc 1992 Oct 7': 2,
#  'Free trade -- North America': 2,
#  'Free trade -- Mexico': 2,
#  'Free trade -- Canada': 2,
#  'Balloon ascensions -- Fiction': 0,
#  'Americans -- Foreign countries -- Fiction': 0,
#  'Mystery fiction': 0,
#  'Civil engineers -- Fiction': 0,
#  'Bridges -- Design and construction -- Fiction': 0,
#  'Boston Mass -- Fiction': 0,
#  'Married people -- Fiction': 0,
#  'Mistresses -- Fiction': 0,
#  'British -- Foreign countries -- Fiction': 0,
#  'Impostors and imposture -- Fiction': 0,
#  'Fourth dimension': 2,
#  'Executions and executioners -- Fiction': 0,
#  'British -- France -- Paris -- Fiction': 0,
#  'French -- England -- London -- Fiction': 0,
#  'London England -- History -- 18th century -- Fiction': 0,
#  'Paris France -- History -- 1789-1799 -- Fiction': 0,
#  'Lookalikes -- Fiction': 0,
#  'Slavery': 2,
#  'African American abolitionists': 2,
#  'E660': 2,
#  'Reconstruction US history 1865-1877': 2,
#  'Essays': 2,
#  'English drama -- Early modern and Elizabethan 1500-1600': 2,
#  'Computer crimes -- United States': 2,
#  'HV': 2,
#  'Telephone -- Corrupt practices -- United States': 2,
#  'Computer programming -- Corrupt practices -- United States': 2,
#  'Trials Murder -- Fiction': 0,
#  'Legal stories': 0,
#  'Passing Identity -- Fiction': 0,
#  'Infants switched at birth -- Fiction': 0,
#  'Voyages around the world -- Fiction': 0,
#  'United States -- Politics and government -- 1933-1945': 2,
#  'E740': 2,
#  'New Deal 1933-1939': 2,
#  'Regency fiction': 0,
#  'Rejection Psychology -- Fiction': 0,
#  'First loves -- Fiction': 0,
#  'Dysfunctional families -- Fiction': 0,
#  'Motherless families -- Fiction': 0,
#  'England -- Social life and customs -- 19th century -- Fiction': 0,
#  'Apes -- Fiction': 0,
#  'Jungles -- Fiction': 0,
#  'Detective and mystery stories English': 0,
#  'Holmes Sherlock Fictitious character -- Fiction': 0,
#  'American poetry': 2,
#  'Man-woman relationships -- Fiction': 0,
#  'Rape victims -- Fiction': 0,
#  'Women household employees -- Fiction': 0,
#  'Children of the rich -- Fiction': 0,
#  'Women murderers -- Fiction': 0,
#  'People with disabilities -- Fiction': 0,
#  'Indiana -- Fiction': 0,
#  'Swamps -- Fiction': 0,
#  'Short stories': 0,
#  'Fathers and daughters -- Fiction': 0,
#  'Violists -- Fiction': 0,
#  'Yorkshire England -- Fiction': 0,
#  'Gardens -- Fiction': 0,
#  'NC': 2,
#  'United States -- Statistics': 2,
#  'Apollo 11 Spacecraft': 2,
#  'Space flight to the moon': 2,
#  'Project Apollo US': 2,
#  'TL': 2,
#  'Music': 2,
#  'M': 2,
#  'Europe -- Fiction': 0,
#  'Walking -- Fiction': 0,
#  'Americans -- Europe -- Fiction': 0,
#  'Treasure troves -- Fiction': 0,
#  'Treasure Island Imaginary place -- Fiction': 0,
#  'England -- Fiction': 0,
#  'Gentry -- England -- Fiction': 0,
#  'Horror tales -- Appreciation -- Fiction': 0,
#  'Marriage -- Economic aspects -- Fiction': 0,
#  'Books and reading -- Fiction': 0,
#  'Mothers and sons -- Fiction': 0,
#  'Mate selection -- Fiction': 0,
#  'Heathlands -- Fiction': 0,
#  'People with visual disabilities -- Fiction': 0,
#  'Earth Planet -- Core -- Fiction': 0,
#  'Apocryphal books Old Testament': 2,
#  'Bible Apocrypha': 2,
#  'Moths -- Fiction': 0,
#  'Mothers and daughters -- Fiction': 0,
#  'Conflict of generations -- Fiction': 0,
#  'Challenger Professor Fictitious character -- Fiction': 0,
#  'Tales -- Arab countries': 0,
#  'PJ': 2,
#  'Fairy tales -- Arab countries': 0,
#  'BR': 2,
#  'Christianity -- Essence genius nature': 2,
#  'Apologetics': 2,
#  'Chesterton G K Gilbert Keith 1874-1936': 2,
#  'Christian pilgrims and pilgrimages -- Fiction': 0,
#  'Christian fiction': 0,
#  'U': 2,
#  'War -- Early works to 1800': 2,
#  'Military art and science -- Early works to 1800': 2,
#  'Belief and doubt -- Fiction': 0,
#  'New York State -- Fiction': 0,
#  'Methodists -- Fiction': 0,
#  'Feminist fiction': 0,
#  'Autobiographical fiction': 0,
#  'Ex-convicts -- Fiction': 0,
#  'Paris France -- Fiction': 0,
#  'Epic literature': 0,
#  'Childrens poetry English': 2,
#  'Orphans -- Juvenile fiction': 1,
#  'Schools -- Juvenile fiction': 1,
#  'London England -- Juvenile fiction': 1,
#  'Girls -- Juvenile fiction': 1,
#  'Boarding schools -- Juvenile fiction': 1,
#  'Women novelists French -- 19th century -- Biography': 0,
#  'Sand George 1804-1876': 0,
#  'Prehistoric peoples -- Fiction': 0,
#  'South America -- Fiction': 0,
#  'Dinosaurs -- Fiction': 0,
#  'Working class -- Fiction': 0,
#  'Meat industry and trade -- Fiction': 0,
#  'Immigrants -- Fiction': 0,
#  'Stockyards -- Fiction': 0,
#  'Lithuanian Americans -- Fiction': 0,
#  'Political fiction': 0,
#  'Country homes -- Fiction': 0,
#  'Adoptees -- Fiction': 0,
#  'Cousins -- Fiction': 0,
#  'Uncles -- Fiction': 0,
#  'United States -- Social life and customs -- Fiction': 0,
#  'Humorous stories American': 0,
#  'Men -- England -- Fiction': 0,
#  'Mayors -- Fiction': 0,
#  'Runaway husbands -- Fiction': 0,
#  'Atonement -- Fiction': 0,
#  'British -- South America -- Fiction': 0,
#  'Ocean travel -- Fiction': 0,
#  'Women travelers -- Fiction': 0,
#  'City and town life -- Fiction': 0,
#  'United States -- Politics and government -- 1775-1783': 2,
#  'Monarchy -- Early works to 1800': 2,
#  'Political science -- Early works to 1800': 2,
#  'Statesmen -- United States -- Biography': 2,
#  'Franklin Benjamin 1706-1790': 2,
#  'Justice -- Early works to 1800': 2,
#  'Utopias -- Early works to 1800': 2,
#  'JC': 2,
#  'Poetry': 2,
#  'Sex discrimination -- Fiction': 0,
#  'Unmarried couples -- Fiction': 0,
#  'Stonemasons -- Fiction': 0,
#  'Children -- Death -- Fiction': 0,
#  'Socialites -- Fiction': 0,
#  'Rich people -- Fiction': 0,
#  'Businessmen -- Fiction': 0,
#  'Police -- England -- Fiction': 0,
#  'Jewelry theft -- Fiction': 0,
#  'East Indians -- England -- Fiction': 0,
#  'Epistolary fiction': 0,
#  'Schools -- Fiction': 0,
#  'Boarding schools -- Fiction': 0,
#  'Women authors -- Fiction': 0,
#  'Women college students -- Fiction': 0,
#  'Letters -- Fiction': 0,
#  'Philanthropists -- Fiction': 0,
#  'Female friendship -- Fiction': 0,
#  'Animal experimentation -- Fiction': 0,
#  'Shipwreck survival -- Fiction': 0,
#  'New Orleans La -- Fiction': 0,
#  'Women -- Louisiana -- New Orleans -- Social conditions -- Fiction': 0,
#  'Louisiana -- Social life and customs -- Fiction': 0,
#  'Self-actualization Psychology -- Fiction': 0,
#  'Social classes -- Fiction': 0,
#  'Inheritance and succession -- Fiction': 0,
#  'Sisters -- Fiction': 0,
#  'Lenz Frederick 1950-': 2,
#  'BL': 2,
#  'Cults -- United States': 2,
#  'Childrens stories American': 1,
#  'Flowers -- Juvenile fiction': 1,
#  'Flowers -- Juvenile poetry': 2,
#  'Fairy tales -- United States': 2,
#  'Fairies -- Juvenile poetry': 2,
#  'Submarines Ships -- Fiction': 0,
#  'Underwater exploration -- Fiction': 0,
#  'San Francisco Calif -- Fiction': 0,
#  'Avarice -- Fiction': 0,
#  'Murderers -- Fiction': 0,
#  'Dentists -- Fiction': 0,
#  'Guardian and ward -- Fiction': 0,
#  'Berkshire Hills Mass -- Fiction': 0,
#  'TR': 2,
#  'Photography': 2,
#  'Daguerreotype': 2,
#  'Quests Expeditions -- Fiction': 0,
#  'Detective and mystery stories': 0,
#  'Hotels -- Fiction': 0,
#  'Venice Italy -- Fiction': 0,
#  'Soldiers -- Fiction': 0,
#  'Runaway teenagers -- Fiction': 0,
#  'Seduction -- Fiction': 0,
#  'New York NY -- Fiction': 0,
#  'British -- New York State -- New York -- Fiction': 0,
#  'Betrayal -- Fiction': 0,
#  'Elopement -- Fiction': 0,
#  'Teenage girls -- Fiction': 0,
#  'Teenage pregnancy -- Fiction': 0,
#  'Booksellers and bookselling -- Fiction': 0,
#  'Mystery and detective stories': 1,
#  'Brooklyn New York NY -- Fiction': 0,
#  'Criminals -- Fiction': 0,
#  'Fu Manchu Doctor Fictitious character -- Fiction': 0,
#  'Supernatural -- Fiction': 0,
#  'Great Britain -- History -- Victoria 1837-1901 -- Fiction': 0,
#  'Portraits -- Fiction': 0,
#  'Appearance Philosophy -- Fiction': 0,
#  'London England -- History -- 1800-1950 -- Fiction': 0,
#  'Conduct of life -- Fiction': 0,
#  'Composers -- Fiction': 0,
#  'Phantom of the Opera Fictitious character -- Fiction': 0,
#  'French fiction -- Translations into English': 0,
#  'Americans -- Italy -- Fiction': 0,
#  'Sculptors -- Fiction': 0,
#  'Rome Italy -- Fiction': 0,
#  'Americans -- France -- Fiction': 0,
#  'Aristocracy Social class -- Fiction': 0,
#  'Separation Psychology -- Fiction': 0,
#  'Culture conflict -- Fiction': 0,
#  'Courtship -- Fiction': 0,
#  'Widows -- Fiction': 0,
#  'British -- Europe -- Fiction': 0,
#  'Europeans -- United States -- Fiction': 0,
#  'Upper class -- Fiction': 0,
#  'Electronic publishing -- Handbooks manuals etc': 2,
#  'AE': 2,
#  'Encyclopedias and dictionaries': 2,
#  'Plantation life -- Maryland -- History -- 19th century': 2,
#  'Slaves -- Maryland -- Social conditions -- 19th century': 2,
#  'Fugitive slaves -- Maryland -- Biography': 2,
#  'Antislavery movements -- United States -- History -- 19th century': 2,
#  'Slaves -- Fiction': 0,
#  'Slavery -- Fiction': 0,
#  'African Americans -- Fiction': 0,
#  'Southern States -- Fiction': 0,
#  'Master and servant -- Fiction': 0,
#  'Plantation life -- Fiction': 0,
#  'Uncle Tom Fictitious character -- Fiction': 0,
#  'Brown Father Fictitious character -- Fiction': 0,
#  'Catholics -- Fiction': 0,
#  'Authors American -- 19th century -- Biography': 2,
#  'Wilderness areas -- Massachusetts -- Walden Woods': 2,
#  'Walden Woods Mass -- Social life and customs': 2,
#  'Natural history -- Massachusetts -- Walden Woods': 2,
#  'Thoreau Henry David 1817-1862 -- Homes and haunts -- Massachusetts -- Walden Woods': 2,
#  'Solitude': 2,
#  'United States -- History': 2,
#  'Civil rights movements': 2,
#  'Martin Luther King Jr Day': 2,
#  'African Americans -- Social conditions -- To 1964': 2,
#  'Yukon River Valley Yukon and Alaska -- Poetry': 0,
#  'Governesses -- Fiction': 0,
#  'Children -- Fiction': 0,
#  'Americans -- England -- Fiction': 0,
#  'British -- United States -- Fiction': 0,
#  'London England -- Social life and customs -- Fiction': 0,
#  'Manners and customs -- Fiction': 0,
#  'New York State -- Social life and customs -- Fiction': 0,
#  'Poets -- Fiction': 0,
#  'Manuscripts -- Collectors and collecting -- Fiction': 0,
#  'Factorials': 2,
#  'Frontier and pioneer life -- Australia -- Poetry': 0,
#  'Australian poetry': 0,
#  'Nature stories': 1,
#  'Feral dogs -- Fiction': 0,
#  'Dogs -- Fiction': 0,
#  'Klondike River Valley Yukon -- Fiction': 0,
#  'Sled dogs -- Fiction': 0,
#  'Animal welfare -- Fiction': 0,
#  'Pet theft -- Fiction': 0,
#  'Philosophy Chinese': 2,
#  'Taoism -- Sacred books': 2,
#  'Working class families -- Fiction': 0,
#  'Young men -- Fiction': 0,
#  'Degeneration -- Fiction': 0,
#  'Trading posts -- Fiction': 0,
#  'Imperialism -- Fiction': 0,
#  'Europeans -- Africa -- Fiction': 0,
#  'Fugitives from justice -- Fiction': 0,
#  'Private investigators -- England -- Fiction': 0,
#  'Painters -- Fiction': 0,
#  'Tahiti French Polynesia  Island -- Fiction': 0,
#  'Legends -- Rome -- Poetry': 2,
#  'Epic poetry Latin -- Translations into English': 2,
#  'Aeneas Legendary character -- Poetry': 2,
#  'Country life -- Rome -- Poetry': 2,
#  'Pastoral poetry Latin -- Translations into English': 2,
#  'Agriculture -- Poetry': 2,
#  'Didactic poetry Latin -- Translations into English': 2,
#  'Gibson William 1914-2008': 0,
#  'Adventure stories English': 0,
#  'Animals -- Fiction': 0,
#  'Mowgli Fictitious character -- Fiction': 0,
#  'India -- History -- 19th century -- Fiction': 0,
#  'Feral children -- Fiction': 0,
#  'India -- Fiction': 0,
#  'United States -- Maps': 2,
#  'Fables': 2,
#  'Fiction': 0,
#  'African American women -- Fiction': 0,
#  'Women slaves -- Fiction': 0,
#  'African American families -- Fiction': 0,
#  'Jefferson Thomas 1743-1826 -- Relations with women -- Fiction': 0,
#  'Children of presidents -- Fiction': 0,
#  'Western stories': 0,
#  'Farmers spouses -- Fiction': 0,
#  'Czech Americans -- Fiction': 0,
#  'PG': 0,
#  'Russian fiction -- Translations into English': 0,
#  'Tolstoy Leo graf 1828-1910 -- Translations into English': 0,
#  'Short stories Russian -- Translations into English': 0,
#  'Pilots and pilotage -- Mississippi River': 2,
#  'Twain Mark 1835-1910 -- Travel -- Mississippi River': 2,
#  'Mississippi River Valley -- Social life and customs -- 19th century': 2,
#  'Mississippi River -- Description and travel': 2,
#  'Persian poetry -- Translations into English': 2,
#  'PK': 2,
#  'AG': 2,
#  'English language -- Dictionaries': 2,
#  'N': 2,
#  'Cave paintings -- France -- Vallon-Pont-dArc': 2,
#  'Chauvet Cave France': 2,
#  'Art Prehistoric -- France -- Vallon-Pont-dArc': 2,
#  'Computer networks -- United States -- History': 2,
#  'Internet -- History': 2,
#  'United States Congress': 2,
#  'Copyright -- United States': 2,
#  'JX': 2,
#  'Copyright International': 2,
#  'Electronic book readers': 2,
#  'World maps': 2,
#  'Troy Extinct city -- Poetry': 2,
#  'Cressida Fictitious character -- Poetry': 2,
#  'Trojan War -- Poetry': 2,
#  'Troilus Legendary character -- Poetry': 2,
#  'Gordon Adam Lindsay 1833-1870': 2,
#  'Australia -- Poetry': 2,
#  'Frontier and pioneer life -- Yukon -- Poetry': 0,
#  'Klondike River Valley Yukon -- Gold discoveries -- Poetry': 0,
#  'Browning Robert 1812-1889 -- Criticism and interpretation': 2,
#  'Browning Robert 1812-1889': 2,
#  'Browning Robert 1812-1889 -- Bibliography': 2,
#  'Poets English -- 20th century -- Biography': 2,
#  'Brooke Rupert 1887-1915': 2,
#  'Poetry Modern -- 20th century': 2,
#  'City and town life -- Poetry': 2,
#  'PT': 2,
#  'Kormkr gmundarson approximately 935-970 -- Romances': 2,
#  'Sagas -- Translations into English': 2,
#  'Christian ethics -- Poetry': 2,
#  'Courtly love -- Poetry': 2,
#  'Christian poetry English Middle': 2,
#  'Love poetry English Middle': 2,
#  'Love-letters -- Fiction': 0,
#  'Women novelists -- Fiction': 0,
#  'Railroad stories': 0,
#  'Wheat farmers -- Fiction': 0,
#  'Mussel Slough Tragedy 1880 -- Fiction': 0,
#  'California -- Fiction': 0,
#  'San Joaquin Valley Calif -- Fiction': 0,
#  'Farmers -- Fiction': 0,
#  'Short stories English': 0,
#  'Country life -- Fiction': 0,
#  'Horses -- Juvenile fiction': 1,
#  'Great Britain -- History -- 19th century -- Juvenile fiction': 1,
#  'Human-animal relationships -- Juvenile fiction': 1,
#  'Reformation -- Germany': 2,
#  'Bible -- Translating': 2,
#  'Catholic Church -- Relations -- Lutheran Church -- Early works to 1800': 2,
#  'Lutheran Church -- Doctrines -- Early works to 1800': 2,
#  'Lutheran Church -- Relations -- Catholic Church -- Early works to 1800': 2,
#  'Lutheran Church -- Creeds -- Early works to 1800': 2,
#  'Indulgences': 2,
#  'Reformation -- Germany -- Sources': 2,
#  'Theology Doctrinal': 2,
#  'Lutheran Church -- Doctrines': 2,
#  'QC': 2,
#  'Manhattan Project US': 2,
#  'D731': 2,
#  'Atomic bomb -- New Mexico -- Testing -- History': 2,
#  'Atomic bomb -- New Mexico -- Los Alamos -- Testing -- History': 2,
#  'TA': 2,
#  'Bell Rock Lighthouse Scotland': 2,
#  'Engineers -- Great Britain -- Biography': 2,
#  'Lighthouses -- Scotland': 2,
#  'Stevenson Robert 1772-1850': 2,
#  'Stephenson family': 2,
#  'Damien Saint Father 1840-1889': 2,
#  'Kinglake Alexander William 1809-1891 -- Travel -- Middle East': 2,
#  'DS': 2,
#  'Middle East -- Description and travel': 2,
#  'France -- Fiction': 0,
#  'Single women -- Fiction': 0,
#  'Atlantis Legendary place -- Fiction': 0,
#  'Lost continents -- Fiction': 0,
#  'Texas -- History -- Revolution 1835-1836 -- Fiction': 0,
#  'Alamo San Antonio Tex -- Siege 1836 -- Fiction': 0,
#  'River life -- Fiction': 0,
#  'United States -- Social life and customs -- 19th century -- Fiction': 0,
#  'New York NY -- History -- 19th century -- Fiction': 0,
#  'Great Britain -- Social life and customs -- 19th century -- Fiction': 0,
#  'Short stories American': 0,
#  'Baseball -- Juvenile fiction': 1,
#  'Boys -- Juvenile fiction': 1,
#  'Adoptees -- Juvenile fiction': 1,
#  'Forgery -- Fiction': 0,
#  'Swindlers and swindling -- Fiction': 0,
#  'Stock exchanges -- Fiction': 0,
#  'Jews -- Fiction': 0,
#  'Capitalists and financiers -- Fiction': 0,
#  'Norwegian Americans -- Fiction': 0,
#  'Prisoners -- Poetry': 0,
#  'Prisons -- Poetry': 0,
#  'Imprisonment -- Poetry': 0,
#  'Fibonacci numbers': 2,
#  'World Wide Web': 2,
#  'Short stories Australian': 0,
#  'Australia -- Social life and customs -- Fiction': 0,
#  'Frontier and pioneer life -- Australia -- Fiction': 0,
#  'Thames River England -- Fiction': 0,
#  'Boats and boating -- England -- Thames River -- Fiction': 0,
#  'Young men -- Travel -- England -- Thames River -- Fiction': 0,
#  'Humorous stories English': 0,
#  'Dreams -- Fiction': 0,
#  'New York NY -- Social life and customs -- 19th century -- Fiction': 0,
#  'Southwest New -- Bibliography': 2,
#  'World War 1914-1918 -- Poetry': 2,
#  'Prince Edward Island -- Juvenile fiction': 1,
#  'Publishers and publishing -- Juvenile fiction': 1,
#  'Childrens stories Canadian': 1,
#  'Authorship -- Juvenile fiction': 1,
#  'New York State -- Poetry': 2,
#  'American poetry -- 19th century': 2,
#  'Fairies -- Poetry': 2,
#  'Alcoholics -- United States -- Biography': 2,
#  'Authors American -- 20th century -- Biography': 2,
#  'London Jack 1876-1916': 2,
#  'Drinking of alcoholic beverages -- United States': 2,
#  'American essays -- 19th century': 2,
#  'Prisoners of war -- Fiction': 0,
#  'French -- England -- Fiction': 0,
#  'India -- Poetry': 2,
#  'Kentucky -- Fiction': 0,
#  'Shasta Mount Calif  Mountain': 2,
#  'Forests and forestry -- West US': 2,
#  'F5903': 2,
#  'West US -- Description and travel': 2,
#  'Islands of the Pacific -- Fiction': 0,
#  'Impersonation -- Fiction': 0,
#  'Health resorts -- Fiction': 0,
#  'Stevenson Robert Louis 1850-1894': 2,
#  'Authors Scottish -- 19th century -- Biography': 2,
#  'Voyages and travels -- Fiction': 0,
#  'E011': 2,
#  'Heroes': 2,
#  'Dakota Indians -- Biography': 2,
#  'Indians of North America -- Biography': 2,
#  'Indian children -- North America': 2,
#  'Eastman Charles Alexander 1858-1939 -- Childhood and youth': 2,
#  'Santee Indians -- Biography': 2,
#  'Santee Indians -- Social life and customs': 2,
#  'Dakota Indians -- Folklore': 2,
#  'Dakota Indians -- Fiction': 0,
#  'Indians of North America -- Fiction': 0,
#  'Indian mythology -- North America': 2,
#  'Indians of North America -- Religion': 2,
#  'Indian philosophy -- North America': 2,
#  'Mdewakanton Indians -- Folklore': 2,
#  'DA': 2,
#  'Barrie Margaret Ogilvy': 2,
#  'Fables Scottish': 0,
#  'Great Britain -- History -- 19th century -- Fiction': 0,
#  'Dracula Count Fictitious character -- Fiction': 0,
#  'Transylvania Romania -- Fiction': 0,
#  'Vampires -- Fiction': 0,
#  'Whitby England -- Fiction': 0,
#  'Nebraska -- Social life and customs -- Fiction': 0,
#  'Vikings -- Fiction': 0,
#  'Grettir smundarson 996-1031 -- Fiction': 2,
#  'Hymns Greek Classical -- Translations into English': 2,
#  'Epic poetry Greek -- Translations into English': 2,
#  'Gods Greek -- Poetry': 2,
#  'Epic poetry Greek': 2,
#  'Hesiod -- Translations into English': 2,
#  'Herbalists -- Fiction': 0,
#  'Jewish families -- Fiction': 0,
#  'Wisconsin -- Fiction': 0,
#  'Jewish fiction': 0,
#  'Jewish girls -- Fiction': 0,
#  'Artists -- Fiction': 0,
#  'United States -- Social life and customs -- 20th century -- Fiction': 0,
#  'McCrae John 1872-1918': 2,
#  'Patriotic poetry': 2,
#  'Women -- Suffrage -- United States': 2,
#  'Shaw Anna Howard 1847-1919': 2,
#  'Women social reformers -- United States -- Biography': 2,
#  'Womens rights -- United States': 2,
#  'Mesmerism -- Fiction': 0,
#  'Suburbs -- Great Britain -- Fiction': 0,
#  'Matthias I King of Hungary 1443-1490 -- Fiction': 0,
#  'Peasant uprisings -- Fiction': 0,
#  'Ball John -1381 -- Fiction': 0,
#  'Tylers Insurrection 1381 -- Fiction': 0,
#  'Automobiles -- Fiction': 0,
#  'Automobile driving -- Fiction': 0,
#  'Holidays': 2,
#  'Childrens literature': 2,
#  'Storytelling': 2,
#  'Economics': 2,
#  'HB': 2,
#  'Property': 2,
#  'Marriage -- Fiction': 0,
#  'Mistaken identity -- Fiction': 0,
#  'Natural history -- California': 2,
#  'California -- History Local': 2,
#  'F8505': 2,
#  'Frontier and pioneer life -- California': 2,
#  'California -- Description and travel': 2,
#  'California -- Social life and customs': 2,
#  'Debutantes -- Fiction': 0,
#  'Authorship -- Fiction': 0,
#  'Maine -- Fiction': 0,
#  'Seaside resorts -- Fiction': 0,
#  'Summer resorts -- Fiction': 0,
#  'Temple University': 2,
#  'BJ': 2,
#  'Success': 2,
#  'Conwell Russell H 1843-1925': 2,
#  'Outlaws -- Fiction': 0,
#  'Great Britain -- History -- Henry III 1216-1272 -- Fiction': 0,
#  'Picaresque literature': 0,
#  'Repentance -- Fiction': 0,
#  'Children of prisoners -- Fiction': 0,
#  'Women -- England -- Fiction': 0,
#  'Prostitutes -- Fiction': 0,
#  'British -- Virginia -- Fiction': 0,
#  'Virginia -- Fiction': 0,
#  'Errors and blunders Literary': 2,
#  'PN': 2,
#  'Fables American': 2,
#  'Wit and humor': 2,
#  'Prisoners -- Fiction': 0,
#  'London England -- History -- 17th century -- Fiction': 0,
#  'Plague -- Fiction': 0,
#  'Great Fire London England 1666 -- Fiction': 0,
#  'Women authors American -- Homes and haunts -- Kansas': 2,
#  'Women -- Kansas -- Intellectual life': 2,
#  'Women and literature -- Kansas': 2,
#  'Kansas -- In literature': 2,
#  'Kansas -- Biography': 2,
#  'Adventure and adventurers -- Fiction': 0,
#  'PC': 2,
#  'Judges -- Fiction': 0,
#  'Fathers and sons -- Fiction': 0,
#  'Scotland -- Fiction': 0,
#  'Scotland -- Social life and customs -- 19th century': 2,
#  'Edinburgh Scotland -- Description and travel': 2,
#  'Comedies': 2,
#  'Princes -- Fiction': 0,
#  'Refugees -- Fiction': 0,
#  'Baseball stories American': 0,
#  'Stevenson Robert Louis 1850-1894 -- Correspondence': 2,
#  'Colvin Sidney 1845-1927 -- Correspondence': 2,
#  'Stevenson Robert Louis 1850-1894 -- Travel -- Samoan Islands': 2,
#  'Authors Scottish -- 19th century -- Correspondence': 2,
#  'Northwest Old -- History -- Revolution 1775-1783 -- Fiction': 0,
#  'Clark George Rogers 1752-1818 -- Fiction': 0,
#  'Louisiana -- Fiction': 0,
#  'Frontier and pioneer life -- Fiction': 0,
#  'PL': 2,
#  'Chinese poetry -- Translations into English': 2,
#  'Roland Legendary character -- Romances': 2,
#  'Epic poetry French -- Translations into English': 2,
#  'Crusades -- First 1096-1099 -- Poetry': 2,
#  'Epic poetry Italian -- Translations into English': 2,
#  'Jerusalem -- History -- Latin Kingdom 1099-1244 -- Poetry': 2,
#  'Godfrey of Bouillon approximately 1060-1100 -- Poetry': 2,
#  'Shipwrecks -- Fiction': 0,
#  'Castaways -- Fiction': 0,
#  'Older women -- Fiction': 0,
#  'Villages -- Fiction': 0,
#  'Soul': 2,
#  'Spiritual warfare -- Fiction': 0,
#  'Choice -- Fiction': 0,
#  'Melancholy -- Poetry': 2,
#  'Cheerfulness -- Poetry': 2,
#  'Didactic poetry': 2,
#  'Eve Biblical figure': 2,
#  'Adam Biblical figure': 2,
#  'New York NY -- History -- 1865-1898 -- Juvenile fiction': 1,
#  'Poverty -- Juvenile fiction': 1,
#  'Helen of Troy Queen of Sparta -- Poetry': 2,
#  'Lyric poetry': 2,
#  'Mythology Greek -- Poetry': 2,
#  'Journalists -- Fiction': 0,
#  'Middle West -- Fiction': 0,
#  'Mines and mineral resources -- Fiction': 0,
#  'Revolutions -- Fiction': 0,
#  'Mining engineers -- Fiction': 0,
#  'Soldiers of fortune -- Fiction': 0,
#  'Americans -- South America -- Fiction': 0,
#  'Industrial arts -- Biography': 2,
#  'T': 2,
#  'Iron industry and trade -- Great Britain -- Biography': 2,
#  'Davis Richard Harding 1864-1916 -- Correspondence': 2,
#  'Davis Richard Harding 1864-1916': 2,
#  'Foreign correspondents -- United States -- Biography': 2,
#  'Authors American -- 19th century -- Correspondence': 2,
#  'Journalists -- 19th century -- Fiction': 0,
#  'African Americans': 2,
#  'American poetry -- African American authors': 2,
#  'Mountain life -- Fiction': 0,
#  'Kentucky -- Social life and customs -- Fiction': 0,
#  'Cumberland Mountains -- Fiction': 0,
#  'CT': 2,
#  'Astor John Jacob 1763-1848': 2,
#  'Businessmen -- United States -- Biography': 2,
#  'Ballads': 2,
#  'Nature study': 2,
#  'QH': 2,
#  'Spain -- History -- 19th century': 2,
#  'DP': 2,
#  'Borrow George 1803-1881 -- Travel -- Spain': 2,
#  'Spain -- Description and travel': 2,
#  'Ohio -- Social life and customs -- Fiction': 0,
#  'Good works Theology': 2,
#  'Princess Ozma Fictitious character -- Juvenile fiction': 1,
#  'Islands -- Juvenile fiction': 1,
#  'Rescues -- Juvenile fiction': 1,
#  'Princesses -- Juvenile fiction': 1,
#  'Cats -- Juvenile fiction': 1,
#  'Animals Mythical -- Juvenile fiction': 1,
#  'Birthdays -- Juvenile fiction': 1,
#  'Revenge -- Juvenile fiction': 1,
#  'Piglets -- Juvenile fiction': 1,
#  'Earthquakes -- Juvenile fiction': 1,
#  'Nephews -- Juvenile fiction': 1,
#  'Mountains -- Juvenile fiction': 1,
#  'Cousins -- Juvenile fiction': 1,
#  'Dragons -- Juvenile fiction': 1,
#  'Kittens -- Juvenile fiction': 1,
#  'Trials -- Juvenile fiction': 1,
#  'Ranches -- Juvenile fiction': 1,
#  'Scotland -- History -- 18th century -- Fiction': 0,
#  'Kidnapping -- Fiction': 0,
#  'Romanies -- Fiction': 0,
#  'Medical fiction': 0,
#  'Fantasy poetry': 2,
#  'Booth William 1829-1912': 2,
#  'Pastoral poetry': 2,
#  'Thoreau Henry David 1817-1862': 2,
#  'Villon Franois 1431-1463': 2,
#  'Whitman Walt 1819-1892': 2,
#  'Pepys Samuel 1633-1703': 2,
#  'Hugo Victor 1802-1885': 2,
#  'Yoshida Shoin 1830-1859': 2,
#  'Literature -- History and criticism': 2,
#  'Burns Robert 1759-1796': 2,
#  'Knox John approximately 1514-1572': 2,
#  'Women -- Social conditions -- Fiction': 0,
#  'Social classes -- United States -- Fiction': 0,
#  'Middle-aged women -- Fiction': 0,
#  'Murder -- Investigation -- Fiction': 0,
#  'Magicians -- Biography': 2,
#  'Magic tricks -- History': 2,
#  'GV': 2,
#  'Pirates -- Juvenile fiction': 1,
#  'Thieves -- Juvenile fiction': 1,
#  'Physical sciences -- Juvenile fiction': 1,
#  'Parent and child -- Juvenile fiction': 1,
#  'War -- Juvenile fiction': 1,
#  'Electricity -- Juvenile fiction': 1,
#  'Spanish fiction -- Translations into English': 0,
#  'Picaresque literature Spanish': 0,
#  'Spain -- Social conditions -- 16th century -- Fiction': 0,
#  'BF': 2,
#  'Spiritualism': 2,
#  'Mountain life -- Juvenile fiction': 1,
#  'United States -- Juvenile fiction': 1,
#  'Identity Philosophical concept -- Juvenile fiction': 1,
#  'Violinists -- Juvenile fiction': 1,
#  'Adoption -- Juvenile fiction': 1,
#  'Love poetry': 2,
#  'Book collecting': 2,
#  'Crowds': 2,
#  'Criminals -- Biography': 2,
#  'Poor women -- Fiction': 0,
#  'Suicide victims -- Fiction': 0,
#  'Slums -- Fiction': 0,
#  'France -- History -- Revolution 1789-1799 -- Causes': 2,
#  'Revolutions': 2,
#  'DC': 2,
#  'Social psychology': 2,
#  'Criminal psychology': 2,
#  'Swindlers and swindling': 2,
#  'Actresses -- Fiction': 0,
#  'Women -- United States -- Fiction': 0,
#  'Traveling sales personnel -- Fiction': 0,
#  'Businesswomen -- Fiction': 0,
#  'McChesney Emma Fictitious character -- Fiction': 0,
#  'Women sales personnel -- Fiction': 0,
#  'Humorous poetry American': 2,
#  'Dialect literature American': 2,
#  'German Americans -- Poetry': 2,
#  'Conduct of life': 2,
#  'Character': 2,
#  'Fantasy fiction English': 0,
#  ...}
# time: 31 ms

# %% [markdown]
# ### Setting the chosen configs

# %%
### loading networks

window = 4
avg_degree = 3

networks = getNetworks(window)
filtered = filterNetworkEdges(networks, avg_degree)
# Out:
# time: 10.2 s

# %%
maxi = 0
id = 0

for G in filtered:
    if G.vcount() > maxi:
        maxi = G.vcount()
        id = G['gutenberg_id']
        
print(maxi, id)
# Out:
# 1950 34395
# time: 0 ns

# %% [markdown]
# ### Checking if accessibility alone is discriminating

# %%
import numpy as np

def get_accessibility_and_symmetry(id, level=2, type='Backbone'):
    path = './pca 300 networks new right/network_' + id + '.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h='+str(level)]), np.mean(df[type+' Accessibility h='+str(level)])


def get_accessibility_mean_and_std(id, level=2):
    path = './pca 300 networks new right/network_' + id + '.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h='+str(level)]), np.std(df['Accessed Nodes h='+str(level)])
# Out:
# time: 0 ns

# %%
from sklearn.metrics import mean_squared_error

def rmse(y_actual, y_predicted):
    y_actual = y_actual[0]
    y_predicted = y_predicted[0]
    return round(sqrt(mean_squared_error(y_actual, y_predicted)), 4)

# %%
### accessebility mean vs. symmetry mean

import pandas as pd
import matplotlib

matplotlib.rcParams.update({'font.size': 13})

accessibilities = []
symmetries = []
targets = []

for G in networks:
    id = G['gutenberg_id']
    acc, sim = get_accessibility_mean_and_std(id)
    accessibilities.append(acc)
    symmetries.append(sim)
    targets.append(get_book_community(id))
    

df = pd.DataFrame()
df['accessibilities'] = accessibilities
df['symmetries'] = symmetries
df['targets'] = targets

fig = plt.figure(figsize=(6, 6))
fig.add_axes([0.1, 0.1, 0.6, 0.6])

for label, df_filt in df.groupby('targets'):
    plt.scatter(df_filt['accessibilities'], df_filt['symmetries'], alpha=0.2, label=label)
    
plt.legend(loc="lower left")
# plt.suptitle("Discriminating genre using accessibility and " + type + " symmetry h=" + str(level))
plt.xlabel("Accessibility h="+str(level))
plt.ylabel(type + " symmetry h="+str(level))

# first barplot
fig.add_axes([0.1, 0.7, 0.6, 0.2])
bins=np.linspace(min(accessibilities), max(accessibilities) + 1, 30)

hor_hist_f = np.histogram(df.loc[df['targets'] == 'fiction']['accessibilities'], bins=bins, density=True)
plt.plot(hor_hist_f[1][:-1], hor_hist_f[0])

hor_hist_o = np.histogram(df.loc[df['targets'] == 'others']['accessibilities'], bins=bins, density=True)
plt.plot(hor_hist_o[1][:-1], hor_hist_o[0])

plt.title("rmse: " + str(rmse(hor_hist_f, hor_hist_o)), fontsize=12)
plt.axis('on')
plt.xticks([])

# # second barplot
fig.add_axes([0.7, 0.1, 0.2, 0.6])
bins=np.linspace(min(symmetries), max(symmetries) + 1, 30)

vert_hist_f = np.histogram(df.loc[df['targets'] == 'fiction']['symmetries'], bins=bins, density=True)
plt.plot(vert_hist_f[0], vert_hist_f[1][:-1])

vert_hist_o = np.histogram(df.loc[df['targets'] == 'others']['symmetries'], bins=bins, density=True)
plt.plot(vert_hist_o[0], vert_hist_o[1][:-1])

plt.title("rmse: " + str(rmse(hor_hist_f, hor_hist_o)), fontsize=12)
plt.axis('on')
plt.yticks([])

# plt.tight_layout()
# plt.savefig('./images/scores/acc_sim_genre_'+str(level)+'_'+type+'.pdf')
plt.show()

# %%
df = pd.DataFrame()
df['means'] = accessibilities
df['stds'] = symmetries
df['targets'] = targets
# Out:
# time: 0 ns

# %%
import seaborn as sns

grid = sns.JointGrid(x=df.sort_values('targets')['means'], y=df.sort_values('targets')['stds'], 
                     data=df.sort_values('targets'), marginal_ticks=True)

g = grid.plot_joint(sns.scatterplot, hue='targets', data=df.sort_values('targets'), s=50, 
                    alpha=0.3, edgecolor='face')

g.ax_joint.set_ylabel('Accessibility std')
g.ax_joint.set_xlabel('Accessibility mean')
g.ax_joint.tick_params(which='major', direction="in", left=True, bottom=True)
plt.setp(g.ax_joint.get_yticklabels()[0], visible=False)
plt.setp(g.ax_joint.get_xticklabels()[0], visible=False)

leg = g.ax_joint.legend(loc="upper right", scatterpoints=1, title="Category")
for lh in leg.legendHandles: 
    lh.set_alpha(0.3)
    lh.set_sizes([50])
    lh.set_edgecolors('face')

sns.kdeplot(x=df.loc[df['targets']=='fiction', 'means'], ax=g.ax_marg_x, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(x=df.loc[df['targets']=='others', 'means'], ax=g.ax_marg_x, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(y=df.loc[df['targets']=='fiction', 'stds'], ax=g.ax_marg_y, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(y=df.loc[df['targets']=='others', 'stds'], ax=g.ax_marg_y, 
            legend=False, bw_method=0.1, alpha=1)

g.ax_marg_x.set_yticks([0.000, 0.015, 0.030])
g.ax_marg_y.set_xticks([0.00, 0.03])

g.ax_marg_x.tick_params(which='major', direction="in", left=True)
g.ax_marg_y.tick_params(which='major', direction="in", bottom=True)

g.savefig('access_mean_std.pdf', bbox_inches='tight')
# g.show()
# Out:
# time: 1.98 s

# %%
def get_accessibility_mean_and_std(id, level):
    path = './pca 300 networks new right/network_' + id + '.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h='+str(level)]), np.std(df['Accessed Nodes h='+str(level)])


def get_symmetry_mean_and_std(id, level):
    path = './pca 300 networks new right/network_' + id + '.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Backbone Accessibility h='+str(level)]), np.std(df['Backbone Accessibility h='+str(level)])
# Out:
# time: 0 ns

# %%
### accessibility mean vs. accessibility std

matplotlib.rcParams.update({'font.size': 13})

means = []
stds = []
targets = []
level = 2

for G in networks:
    id = G['gutenberg_id']
    mean, std = get_accessibility_mean_and_std(id, level)
    means.append(mean)
    stds.append(std)
    targets.append(get_book_community(id))


df = pd.DataFrame()
df['means'] = means
df['stds'] = stds
df['targets'] = targets

fig = plt.figure(figsize=(6, 6))
fig.add_axes([0.1, 0.1, 0.6, 0.6])

for label, df_filt in df.groupby('targets'):
    plt.scatter(df_filt['means'], df_filt['stds'], alpha=0.2, label=label)
    
plt.legend(loc="lower right")
# plt.suptitle("Discriminating genre using accessibility h=" + str(level))

plt.xlabel("Accessibility mean")
plt.ylabel("Accessibility std")
plt.xticks([20, 40, 60, 80, 100])

# first barplot
fig.add_axes([0.1, 0.7, 0.6, 0.2])
bins=np.linspace(min(means), max(means) + 1, 30)

hor_hist_f = np.histogram(df.loc[df['targets'] == 'fiction']['means'], bins=bins, density=True)
plt.plot(hor_hist_f[1][:-1], hor_hist_f[0])

hor_hist_o = np.histogram(df.loc[df['targets'] == 'others']['means'], bins=bins, density=True)
plt.plot(hor_hist_o[1][:-1], hor_hist_o[0])

plt.title("rmse: " + str(rmse(hor_hist_f, hor_hist_o)), fontsize=12)
plt.axis('on')
plt.xticks([])

# # second barplot
fig.add_axes([0.7, 0.1, 0.2, 0.6])
bins=np.linspace(min(stds), max(stds) + 1, 30)

vert_hist_f = np.histogram(df.loc[df['targets'] == 'fiction']['stds'], bins=bins, density=True)
plt.plot(vert_hist_f[0], vert_hist_f[1][:-1])

vert_hist_o = np.histogram(df.loc[df['targets'] == 'others']['stds'], bins=bins, density=True)
plt.plot(vert_hist_o[0], vert_hist_o[1][:-1])

plt.title("rmse: " + str(rmse(vert_hist_f, vert_hist_o)), fontsize=12)
plt.axis('on')
plt.yticks([])

# plt.tight_layout()
plt.savefig('./images/scores/only_acc_genre_h'+str(level)+'.pdf')
plt.show()
# Out:
# time: 2.92 s

# %% [markdown]
# ## Discriminating real from meaningless

# %%
### accessibility mean vs. symmetry mean

df = pd.DataFrame()
df['means'] = means
df['stds'] = stds
df['targets'] = targets


grid = sns.JointGrid(x=df.sort_values('targets')['means'], y=df.sort_values('targets')['stds'], 
                     data=df.sort_values('targets'), marginal_ticks=True)

g = grid.plot_joint(sns.scatterplot, hue='targets', data=df.sort_values('targets'), s=50, 
                    alpha=0.3, edgecolor='face')

g.ax_joint.set_ylabel('Accessibility std')
g.ax_joint.set_xlabel('Accessibility mean')
g.ax_joint.tick_params(which='major', direction="in", left=True, bottom=True)
plt.setp(g.ax_joint.get_yticklabels()[0], visible=False)
plt.setp(g.ax_joint.get_xticklabels()[0], visible=False)

leg = g.ax_joint.legend(loc="lower right", scatterpoints=1, title="Category")
for lh in leg.legendHandles: 
    lh.set_alpha(0.3)
    lh.set_sizes([50])
    lh.set_edgecolors('face')

sns.kdeplot(x=df.loc[df['targets']=='meaningless', 'means'], ax=g.ax_marg_x, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(x=df.loc[df['targets']=='real', 'means'], ax=g.ax_marg_x, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(y=df.loc[df['targets']=='meaningless', 'stds'], ax=g.ax_marg_y, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(y=df.loc[df['targets']=='real', 'stds'], ax=g.ax_marg_y, 
            legend=False, bw_method=0.1, alpha=1)

g.ax_marg_x.set_yticks([0.000, 0.015, 0.030])
g.ax_marg_y.set_xticks([0.00, 0.03])

g.ax_marg_x.tick_params(which='major', direction="in", left=True)
g.ax_marg_y.tick_params(which='major', direction="in", bottom=True)




g.savefig('access_mean_std_meaningless.pdf', bbox_inches='tight')
# g.show()
# Out:
# time: 2.16 s

# %%
def get_accessibility_and_symmetry_random(id, level, type='Merged'):
    path = './pca 300 networks new right/network_' + id + '_RP.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h='+str(level)]), np.mean(df[type+' Accessibility h='+str(level)])


def get_accessibility_mean_and_std_random(id, level):
    path = './pca 300 networks new right/network_' + id + '_RP.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h='+str(level)]), np.std(df['Accessed Nodes h='+str(level)])
# Out:
# time: 0 ns

# %%
### media acessibilidade vs. std acessibilidade

matplotlib.rcParams.update({'font.size': 13})

means = []
stds = []
targets = []
level = 2

for G in networks:
    id = G['gutenberg_id']
    mean, std = get_accessibility_mean_and_std(id, level)
    means.append(mean)
    stds.append(std)
    targets.append("real")
    
    mean, std = get_accessibility_mean_and_std_random(id, level)
    means.append(mean)
    stds.append(std)
    targets.append("meaningless")


df = pd.DataFrame()
df['means'] = means
df['stds'] = stds
df['targets'] = targets

fig = plt.figure(figsize=(6, 6))
fig.add_axes([0.1, 0.1, 0.6, 0.6])

for label, df_filt in df.groupby('targets'):
    plt.scatter(df_filt['means'], df_filt['stds'], alpha=0.2, label=label)
    
# plt.legend()
plt.legend(loc="lower right")
# plt.suptitle("Discriminating real from meaningless using accessibility h=" + str(level))

plt.xlabel("Accessibility mean")
plt.ylabel("Accessibility std")
plt.xticks([20, 40, 60, 80, 100, 120, 140])

# first barplot
fig.add_axes([0.1, 0.7, 0.6, 0.2])
bins=np.linspace(min(means), max(means) + 1, 30)

hor_hist_f = np.histogram(df.loc[df['targets'] == 'meaningless']['means'], bins=bins, density=True)
plt.plot(hor_hist_f[1][:-1], hor_hist_f[0])

hor_hist_o = np.histogram(df.loc[df['targets'] == 'real']['means'], bins=bins, density=True)
plt.plot(hor_hist_o[1][:-1], hor_hist_o[0])

plt.title("rmse: " + str(rmse(hor_hist_f, hor_hist_o)), fontsize=12)
plt.axis('on')
plt.xticks([])

# # second barplot
fig.add_axes([0.7, 0.1, 0.2, 0.6])
bins=np.linspace(min(stds), max(stds) + 1, 30)

vert_hist_f = np.histogram(df.loc[df['targets'] == 'meaningless']['stds'], bins=bins, density=True)
plt.plot(vert_hist_f[0], vert_hist_f[1][:-1])

vert_hist_o = np.histogram(df.loc[df['targets'] == 'real']['stds'], bins=bins, density=True)
plt.plot(vert_hist_o[0], vert_hist_o[1][:-1])

plt.title("rmse: " + str(rmse(vert_hist_f, vert_hist_o)), fontsize=12)
plt.axis('on')
plt.yticks([])

# plt.tight_layout()
plt.savefig('./images/scores/random/only_acc_random_h'+str(level)+'.pdf')
plt.show()

# %%
### accessibility mean vs. symmetry mean

matplotlib.rcParams.update({'font.size': 13})

accessibilities = []
symmetries = []
targets = []
level = 2
type = 'Backbone'

for G in networks:
    id = G['gutenberg_id']
    acc, sim = get_accessibility_and_symmetry(id, level, type)
    accessibilities.append(acc)
    symmetries.append(sim)
    targets.append("real")
    
    acc, sim = get_accessibility_and_symmetry_random(id, level, type)
    accessibilities.append(acc)
    symmetries.append(sim)
    targets.append("meaningless")
    

df = pd.DataFrame()
df['accessibilities'] = accessibilities
df['symmetries'] = symmetries
df['targets'] = targets

fig = plt.figure(figsize=(6, 6))
fig.add_axes([0.1, 0.1, 0.6, 0.6])

for label, df_filt in df.groupby('targets'):
    plt.scatter(df_filt['accessibilities'], df_filt['symmetries'], alpha=0.2, label=label)
    
plt.legend(loc="lower left")
# plt.suptitle("Discriminating real from meaningless using accessibility and " + type + " symmetry h=" + str(level))
plt.xlabel("Accessibility h="+str(level))
plt.ylabel(type + " symmetry h="+str(level))

# first barplot
fig.add_axes([0.1, 0.7, 0.6, 0.2])
bins=np.linspace(min(accessibilities), max(accessibilities) + 1, 30)

hor_hist_f = np.histogram(df.loc[df['targets'] == 'meaningless']['accessibilities'], bins=bins, density=True)
plt.plot(hor_hist_f[1][:-1], hor_hist_f[0])

hor_hist_o = np.histogram(df.loc[df['targets'] == 'real']['accessibilities'], bins=bins, density=True)
plt.plot(hor_hist_o[1][:-1], hor_hist_o[0])

plt.title("rmse: " + str(rmse(hor_hist_f, hor_hist_o)), fontsize=12)
plt.axis('on')
plt.xticks([])

# # second barplot
fig.add_axes([0.7, 0.1, 0.2, 0.6])
bins=np.linspace(min(symmetries), max(symmetries) + 1, 30)

vert_hist_f = np.histogram(df.loc[df['targets'] == 'meaningless']['symmetries'], bins=bins, density=True)
plt.plot(vert_hist_f[0], vert_hist_f[1][:-1])

vert_hist_o = np.histogram(df.loc[df['targets'] == 'real']['symmetries'], bins=bins, density=True)
plt.plot(vert_hist_o[0], vert_hist_o[1][:-1])

plt.title("rmse: " + str(rmse(hor_hist_f, hor_hist_o)), fontsize=12)
plt.axis('on')
plt.yticks([])

# plt.tight_layout()
plt.savefig('./images/scores/random/acc_sim_random_'+str(level)+'_'+type+'.pdf')
plt.show()

# %%
### accessibility mean vs. symmetry mean

df = pd.DataFrame()
df['means'] = accessibilities
df['stds'] = symmetries
df['targets'] = targets


grid = sns.JointGrid(x=df.sort_values('targets')['means'], y=df.sort_values('targets')['stds'], 
                     data=df.sort_values('targets'), marginal_ticks=True)

g = grid.plot_joint(sns.scatterplot, hue='targets', data=df.sort_values('targets'), s=50, 
                    alpha=0.3, edgecolor='face')

g.ax_joint.set_ylabel('Backbone symmetry mean')
g.ax_joint.set_xlabel('Accessibility mean')
g.ax_joint.tick_params(which='major', direction="in", left=True, bottom=True)
plt.setp(g.ax_joint.get_yticklabels()[0], visible=False)
plt.setp(g.ax_joint.get_xticklabels()[0], visible=False)

leg = g.ax_joint.legend(loc="upper right", scatterpoints=1, title="Category")
for lh in leg.legendHandles: 
    lh.set_alpha(0.3)
    lh.set_sizes([50])
    lh.set_edgecolors('face')

sns.kdeplot(x=df.loc[df['targets']=='meaningless', 'means'], ax=g.ax_marg_x, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(x=df.loc[df['targets']=='real', 'means'], ax=g.ax_marg_x, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(y=df.loc[df['targets']=='meaningless', 'stds'], ax=g.ax_marg_y, 
            legend=False, bw_method=0.1, alpha=1)
sns.kdeplot(y=df.loc[df['targets']=='real', 'stds'], ax=g.ax_marg_y, 
            legend=False, bw_method=0.1, alpha=1)

g.ax_marg_x.set_yticks([0.000, 0.015, 0.030])
g.ax_marg_y.set_xticks([0.00, 0.03])

g.ax_marg_x.tick_params(which='major', direction="in", left=True)
g.ax_marg_y.tick_params(which='major', direction="in", bottom=True)


g.savefig('access_sym_mean_meaningless.pdf', bbox_inches='tight')
# g.show()
# Out:
# time: 2.08 s

# %% [markdown]
# ## New plots

# %%
### code to retrieve all networks from 'pca 300 networks' folder and store it in an array 

def getNetworkIds():

    ids = []
    path = './pca 300 networks new right/'
    directory = os.fsencode(path)

    for file in os.listdir(directory):
        filename = path + os.fsdecode(file)
        if filename.endswith("_RP.tsv"):
            # getting gutenberg_id
            start = len(path) + len('network_')
            end = len('_RP.tsv')
            gutenberg_id = filename[start:-end]
            ids.append(gutenberg_id)
            
    return ids

# %%
import sys
import inspect
import scipy.stats

def CountQuads(Arr2D, point):
    """ Computes the probabilities of finding points in each 4 quadrant
    defined by a vertical and horizontal lines crossing the point, by counting
    the proportion of points in Arr2D in each quadrant.
    :param list Arr2D: Array of points to be counted.
    :param array point: A 2 element list, point, which is the center of
    4 square quadrants.
    :returns: a tuple of 4 floats.  The probabilities of finding a point in
    each quadrants, with point as the origin.  p stands for positive, n for
    negative, with the first and second positions meaning the x and y
    directions respectively.
    """
    if isinstance(point, list):
        point = np.asarray((np.ravel(point)))
    elif type(point).__module__+type(point).__name__ == 'numpyndarray':
        point = np.ravel(point.copy())
    else:
        raise TypeError('Input point is neither list nor numpyndarray')
    if len(point) != 2:
        return
    if isinstance(Arr2D, list):
        Arr2D = np.asarray((Arr2D))
    elif type(Arr2D).__module__+type(Arr2D).__name__ == 'numpyndarray':
        pass
    else:
        raise TypeError('Input Arr2D is neither list nor numpyndarray')
    if Arr2D.shape[1] > Arr2D.shape[0]:  # Reshape to A[row,column]
        Arr2D = Arr2D.copy().T
    if Arr2D.shape[1] != 2:
        raise TypeError('Input Arr2D is not 2D')
    # The pp of Qpp refer to p for 'positive' and n for 'negative' quadrants.
    # In order. first subscript is x, second is y.
    Qpp = Arr2D[(Arr2D[:, 0] > point[0]) & (Arr2D[:, 1] > point[1]), :]
    Qnp = Arr2D[(Arr2D[:, 0] < point[0]) & (Arr2D[:, 1] > point[1]), :]
    Qpn = Arr2D[(Arr2D[:, 0] > point[0]) & (Arr2D[:, 1] < point[1]), :]
    Qnn = Arr2D[(Arr2D[:, 0] < point[0]) & (Arr2D[:, 1] < point[1]), :]
    # Normalized fractions:
    ff = 1./len(Arr2D)
    fpp = len(Qpp)*ff
    fnp = len(Qnp)*ff
    fpn = len(Qpn)*ff
    fnn = len(Qnn)*ff
    # NOTE:  all the f's are supposed to sum to 1.0. Float representation
    # cause SOMETIMES sum to 1.000000002 or something. I don't know how to
    # test for that reliably, OR what to do about it yet. Keep in mind.
    return(fpp, fnp, fpn, fnn)

def FuncQuads(func2D, point, xlim, ylim, rounddig=4):
    """ Computes the probabilities of finding points in each 4 quadrant
    defined by a vertical and horizontal lines crossing the point, by
    integrating the density function func2D in each quadrant.
    :param array func2D: Density function that takes 2 arguments: x and y.
    :param list point: A 2 element list, point, which is the center of 4
    square quadrants.
    :param array xlim,ylim: Domain of numerical integration necessary to
    compute the quadrant probabilities.
    :returns: a tuple of 4 floats. The probabilities of finding a point in
    each quadrants, with point as the origin.  p stands for positive,
    n for negative, with the first and second positions meaning the x and y
    directions respectively.
    """
    if callable(func2D):
        if len(inspect.getfullargspec(func2D)[0]) != 2:
            raise TypeError('Input func2D is not a function with 2 arguments')
        pass
    else:
        raise TypeError('Input func2D is not a function')
    # If xlim, ylim and point are not lists or ndarray, exit.
    if isinstance(point, list):
        point = np.asarray((np.ravel(point)))
    elif type(point).__module__+type(point).__name__ == 'numpyndarray':
        point = np.ravel(point.copy())
    else:
        raise TypeError('Input point is not a list or numpyndarray')
    if len(point) != 2:
        raise TypeError('Input point has not exactly 2 elements')
    if isinstance(xlim, list):
        xlim = np.asarray((np.sort(np.ravel(xlim))))
    elif type(xlim).__module__+type(xlim).__name__ == 'numpyndarray':
        xlim = np.sort(np.ravel(xlim.copy()))
    else:
        raise TypeError('Input xlim is not a list or ndarray')
    if len(xlim) != 2:
        raise TypeError('Input xlim has not exactly 2 elements')
    if xlim[0] == xlim[1]:
        raise TypeError('Input xlim[0] should be different to xlim[1]')
    if isinstance(ylim, list):
        ylim = np.asarray((np.sort(np.ravel(ylim))))
    elif type(ylim).__module__+type(ylim).__name__ == 'numpyndarray':
        ylim = np.sort(np.ravel(ylim.copy()))
    else:
        raise TypeError('Input ylim is not a list or ndarray')
    if len(ylim) != 2:
        raise TypeError('Input ylim has not exactly 2 elements')
    if ylim[0] == ylim[1]:
        raise TypeError('Input ylim[0] should be different to ylim[1]')
    # Numerical integration to find the quadrant probabilities.
    totInt = scipy.integrate.dblquad(func2D, *xlim,
                                     lambda x: np.amin(ylim),
                                     lambda x: np.amax(ylim))[0]
    Qpp = scipy.integrate.dblquad(func2D, point[0], np.amax(xlim),
                                  lambda x: point[1],
                                  lambda x: np.amax(ylim))[0]
    Qpn = scipy.integrate.dblquad(func2D, point[0], np.amax(xlim),
                                  lambda x: np.amin(ylim),
                                  lambda x: point[1])[0]
    Qnp = scipy.integrate.dblquad(func2D, np.amin(xlim), point[0],
                                  lambda x: point[1],
                                  lambda x: np.amax(ylim))[0]
    Qnn = scipy.integrate.dblquad(func2D, np.amin(xlim), point[0],
                                  lambda x: np.amin(ylim),
                                  lambda x: point[1])[0]
    fpp = round(Qpp/totInt, rounddig)
    fnp = round(Qnp/totInt, rounddig)
    fpn = round(Qpn/totInt, rounddig)
    fnn = round(Qnn/totInt, rounddig)
    return(fpp, fnp, fpn, fnn)

def Qks(alam, iter=100, prec=1e-17):
    """ Computes the value of the KS probability function, as a function of
    alam, the D statistic. From *Numerical recipes in C* page 623: '[...]
    the K–S statistic useful is that its distribution in the case of the null
    hypothesis (data sets drawn from the same distribution) can be calculated,
    at least to useful approximation, thus giving the significance of any
    observed nonzero value of D.' (D being the KS statistic).
    :param float alam: D statistic.
    :param int iter: Number of iterations to be perfomed. On non-convergence,
    returns 1.0.
    :param float prec: Convergence criteria of the qks. Stops converging if
    that precision is attained.
    :returns: a float. The significance level of the observed D statistic.
    """
    # If j iterations are performed, meaning that toadd
    # is still 2 times larger than the precision.
    if isinstance(alam, int) | isinstance(alam, float):
        pass
    else:
        raise TypeError('Input alam is neither int nor float')
    toadd = [1]
    qks = 0.
    j = 1
    while (j < iter) & (abs(toadd[-1]) > prec*2):
        toadd.append(2.*(-1.)**(j-1.)*np.exp(-2.*j**2.*alam**2.))
        qks += toadd[-1]
        j += 1
    if (j == iter) | (qks > 1):  # If no convergence after j iter, return 1.0
        return(1.0)
    if qks < prec:
        return(0.)
    else:
        return(qks)
    
def ks2d2s(Arr2D1, Arr2D2):
    """ ks stands for Kolmogorov-Smirnov, 2d for 2 dimensional,
    2s for 2 samples.
    KS test for goodness-of-fit on two 2D samples. Tests the hypothesis that
    the two samples are from the same distribution.
    :param array Arr2D1: 2D array of points/samples.
    :param array Arr2D2: 2D array of points/samples.
    :returns: a tuple of two floats. First, the two-sample K-S statistic.
    If this value is higher than the significance level of the hypothesis,
    it is rejected. Second, the significance level of *d*. Small values of
    prob show that the two samples are significantly different.
    """
    if type(Arr2D1).__module__+type(Arr2D1).__name__ == 'numpyndarray':
        pass
    else:
        raise TypeError('Input Arr2D1 is neither list nor numpyndarray')
    if Arr2D1.shape[1] > Arr2D1.shape[0]:
        Arr2D1 = Arr2D1.copy().T
    if type(Arr2D2).__module__+type(Arr2D2).__name__ == 'numpyndarray':
        pass
    else:
        raise TypeError('Input Arr2D2 is neither list nor numpyndarray')
    if Arr2D2.shape[1] > Arr2D2.shape[0]:
        Arr2D2 = Arr2D2.copy().T
    if Arr2D1.shape[1] != 2:
        raise TypeError('Input Arr2D1 is not 2D')
    if Arr2D2.shape[1] != 2:
        raise TypeError('Input Arr2D2 is not 2D')
    d1, d2 = 0., 0.
    for point1 in Arr2D1:
        fpp1, fmp1, fpm1, fmm1 = CountQuads(Arr2D1, point1)
        fpp2, fmp2, fpm2, fmm2 = CountQuads(Arr2D2, point1)
        d1 = max(d1, abs(fpp1-fpp2))
        d1 = max(d1, abs(fpm1-fpm2))
        d1 = max(d1, abs(fmp1-fmp2))
        d1 = max(d1, abs(fmm1-fmm2))
    for point2 in Arr2D2:
        fpp1, fmp1, fpm1, fmm1 = CountQuads(Arr2D1, point2)
        fpp2, fmp2, fpm2, fmm2 = CountQuads(Arr2D2, point2)
        d2 = max(d2, abs(fpp1-fpp2))
        d2 = max(d2, abs(fpm1-fpm2))
        d2 = max(d2, abs(fmp1-fmp2))
        d2 = max(d2, abs(fmm1-fmm2))
    d = (d1+d2)/2.
    sqen = np.sqrt(len(Arr2D1)*len(Arr2D2)/(len(Arr2D1)+len(Arr2D2)))
    R1 = scipy.stats.pearsonr(Arr2D1[:, 0], Arr2D1[:, 1])[0]
    R2 = scipy.stats.pearsonr(Arr2D2[:, 0], Arr2D2[:, 1])[0]
    RR = np.sqrt(1.-(R1*R1+R2*R2)/2.)
    prob = Qks(d*sqen/(1.+RR*(0.25-0.75/sqen)))
    # Small values of prob show that the two samples are significantly
    # different. Prob is the significance level of an observed value of d.
    # NOT the same as the significance level that ou set and compare to D.
    #return(d, prob)
    return round(d, 4)

# %%
def get_accessibility_and_symmetry(id):
    path = './pca 300 networks new right/network_' + id + '.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h=2']), np.mean(df['Backbone Accessibility h=2'])


def get_accessibility_mean_and_std(id):
    path = './pca 300 networks new right/network_' + id + '.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h=2']), np.std(df['Accessed Nodes h=2'])

def get_accessibility_and_symmetry_random(id):
    path = './pca 300 networks new right/network_' + id + '_RP.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h=2']), np.mean(df['Backbone Accessibility h=2'])


def get_accessibility_mean_and_std_random(id):
    path = './pca 300 networks new right/network_' + id + '_RP.tsv'
    df = pd.read_csv(path, sep='\t')
    return np.mean(df['Accessed Nodes h=2']), np.std(df['Accessed Nodes h=2'])

# %% [markdown]
# ### Accessibility vs. symmetry: fiction & others

# %%
matplotlib.rcParams.update({'font.size': 13})

accessibilities = []
symmetries = []
targets = []

for id in getNetworkIds():
    acc, sim = get_accessibility_and_symmetry(id)
    accessibilities.append(acc)
    symmetries.append(sim)
    targets.append(get_book_community(id))
    

df = pd.DataFrame()
df['accessibilities'] = accessibilities
df['symmetries'] = symmetries
df['targets'] = targets

# %%
sns.set(font_scale = 1.0)
sns.set_style('white')
plt.rcParams.update({'font.size': 12})
custom_palette = ["#1f77b4", "#ff7f0e"]
sns.set_palette(palette = custom_palette)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

grid = sns.JointGrid(x=df.sort_values('targets')['accessibilities'], y=df.sort_values('targets')['symmetries'], 
                     data=df.sort_values('targets'), marginal_ticks=True)

g = grid.plot_joint(sns.scatterplot, hue='targets', data=df.sort_values('targets'), s=50, alpha=0.3, edgecolor='face')

g.ax_joint.set_ylabel('Symmetry mean')
g.ax_joint.set_xlabel('Accessibility mean')
g.ax_joint.tick_params(which='major', direction="in", left=True, bottom=True)
plt.setp(g.ax_joint.get_yticklabels()[-1], visible=False)
plt.setp(g.ax_joint.get_xticklabels()[-1], visible=False)

leg = g.ax_joint.legend(loc="upper right", scatterpoints=1)
for lh in leg.legendHandles: 
    lh.set_alpha(0.3)
    lh.set_sizes([50])
    lh.set_edgecolors('face')

sns.kdeplot(x=df.loc[df['targets']=='fiction', 'accessibilities'], ax=g.ax_marg_x, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(x=df.loc[df['targets']=='others', 'accessibilities'], ax=g.ax_marg_x, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(y=df.loc[df['targets']=='fiction', 'symmetries'], ax=g.ax_marg_y, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(y=df.loc[df['targets']=='others', 'symmetries'], ax=g.ax_marg_y, legend=False, bw_method=0.1, alpha=1, linewidth=2)

g.ax_marg_x.set_yticks([0.00, 0.03])
g.ax_marg_y.set_xticks([0, 20])

g.ax_marg_x.tick_params(which='major', direction="in", left=True)
g.ax_marg_y.tick_params(which='major', direction="in", bottom=True)

g.ax_joint.text(17, 0.84, "KS:\n" + str(ks2d2s(np.array(df.loc[df['targets']=='fiction', ['accessibilities', 'symmetries']]), np.array(df.loc[df['targets']=='others', ['accessibilities', 'symmetries']]))))

g.fig.set_size_inches((3.5, 3.5))
g.fig.set_rasterized(True)

g.savefig('access_sym.pdf', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Accessibility mean and standard deviation: fiction & others

# %%
matplotlib.rcParams.update({'font.size': 13})

accessibilities = []
symmetries = []
targets = []

for id in getNetworkIds():
    mean, std = get_accessibility_mean_and_std(id)
    accessibilities.append(mean)
    symmetries.append(std)
    targets.append(get_book_community(id))
    

df = pd.DataFrame()
df['accessibilities'] = accessibilities
df['symmetries'] = symmetries
df['targets'] = targets

# %%
sns.set(font_scale = 1.0)
sns.set_style('white')
plt.rcParams.update({'font.size': 12})
custom_palette = ["#1f77b4", "#ff7f0e"]
sns.set_palette(palette = custom_palette)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

grid = sns.JointGrid(x=df.sort_values('targets')['accessibilities'], y=df.sort_values('targets')['symmetries'], 
                     data=df.sort_values('targets'), marginal_ticks=True)

g = grid.plot_joint(sns.scatterplot, hue='targets', data=df.sort_values('targets'), s=50, alpha=0.3, edgecolor='face')

g.ax_joint.set_ylabel('Accessibility std')
g.ax_joint.set_xlabel('Accessibility mean')
g.ax_joint.tick_params(which='major', direction="in", left=True, bottom=True)
plt.setp(g.ax_joint.get_yticklabels()[-1], visible=False)
plt.setp(g.ax_joint.get_xticklabels()[-1], visible=False)

leg = g.ax_joint.legend(loc="lower right", scatterpoints=1)
for lh in leg.legendHandles: 
    lh.set_alpha(0.3)
    lh.set_sizes([50])
    lh.set_edgecolors('face')

sns.kdeplot(x=df.loc[df['targets']=='fiction', 'accessibilities'], ax=g.ax_marg_x, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(x=df.loc[df['targets']=='others', 'accessibilities'], ax=g.ax_marg_x, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(y=df.loc[df['targets']=='fiction', 'symmetries'], ax=g.ax_marg_y, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(y=df.loc[df['targets']=='others', 'symmetries'], ax=g.ax_marg_y, legend=False, bw_method=0.1, alpha=1, linewidth=2)

g.ax_marg_x.set_yticks([0.00, 0.03])
g.ax_marg_y.set_xticks([0, 0.03])

g.ax_marg_x.tick_params(which='major', direction="in", left=True)
g.ax_marg_y.tick_params(which='major', direction="in", bottom=True)

g.ax_joint.text(20, 125, "KS:\n" + str(ks2d2s(np.array(df.loc[df['targets']=='fiction', ['accessibilities', 'symmetries']]), np.array(df.loc[df['targets']=='others', ['accessibilities', 'symmetries']]))))

g.fig.set_size_inches((3.5, 3.5))
g.fig.set_rasterized(True)

g.savefig('access.pdf', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Accessibility vs. symmetry: real & meaningless

# %%
matplotlib.rcParams.update({'font.size': 13})

accessibilities = []
symmetries = []
targets = []

for id in getNetworkIds():
    mean, std = get_accessibility_and_symmetry(id)
    accessibilities.append(mean)
    symmetries.append(std)
    targets.append('real')
    
for id in getNetworkIds():
    mean, std = get_accessibility_and_symmetry_random(id)
    accessibilities.append(mean)
    symmetries.append(std)
    targets.append('meaningless')
    

df = pd.DataFrame()
df['accessibilities'] = accessibilities
df['symmetries'] = symmetries
df['targets'] = targets

# %%
sns.set(font_scale = 1.0)
sns.set_style('white')
plt.rcParams.update({'font.size': 12})
custom_palette = ["#1f77b4", "#ff7f0e"]
sns.set_palette(palette = custom_palette)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

grid = sns.JointGrid(x=df.sort_values('targets')['accessibilities'], y=df.sort_values('targets')['symmetries'], 
                     data=df.sort_values('targets'), marginal_ticks=True)

g = grid.plot_joint(sns.scatterplot, hue='targets', data=df.sort_values('targets'), s=50, alpha=0.3, edgecolor='face')

g.ax_joint.set_ylabel('Symmetry mean')
g.ax_joint.set_xlabel('Accessibility mean')
g.ax_joint.tick_params(which='major', direction="in", left=True, bottom=True)
plt.setp(g.ax_joint.get_yticklabels()[-1], visible=False)
plt.setp(g.ax_joint.get_xticklabels()[-1], visible=False)

leg = g.ax_joint.legend(loc="upper right", scatterpoints=1)
for lh in leg.legendHandles: 
    lh.set_alpha(0.3)
    lh.set_sizes([50])
    lh.set_edgecolors('face')

sns.kdeplot(x=df.loc[df['targets']=='meaningless', 'accessibilities'], ax=g.ax_marg_x, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(x=df.loc[df['targets']=='real', 'accessibilities'], ax=g.ax_marg_x, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(y=df.loc[df['targets']=='meaningless', 'symmetries'], ax=g.ax_marg_y, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(y=df.loc[df['targets']=='real', 'symmetries'], ax=g.ax_marg_y, legend=False, bw_method=0.1, alpha=1, linewidth=2)

g.ax_marg_x.set_yticks([0.00, 0.03])
g.ax_marg_y.set_xticks([0, 20])

g.ax_marg_x.tick_params(which='major', direction="in", left=True)
g.ax_marg_y.tick_params(which='major', direction="in", bottom=True)

g.ax_joint.text(7, 0.82, "KS:\n" + str(ks2d2s(np.array(df.loc[df['targets']=='real', ['accessibilities', 'symmetries']]), np.array(df.loc[df['targets']=='meaningless', ['accessibilities', 'symmetries']]))))

g.fig.set_size_inches((3.5, 3.5))
g.fig.set_rasterized(True)

g.savefig('access_sym_random.pdf', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Accessibility mean and standard deviation: real & meaningless

# %%
matplotlib.rcParams.update({'font.size': 13})

accessibilities = []
symmetries = []
targets = []

for id in getNetworkIds():
    mean, std = get_accessibility_mean_and_std(id)
    accessibilities.append(mean)
    symmetries.append(std)
    targets.append('real')
    
for id in getNetworkIds():
    mean, std = get_accessibility_mean_and_std_random(id)
    accessibilities.append(mean)
    symmetries.append(std)
    targets.append('meaningless')
    

df = pd.DataFrame()
df['accessibilities'] = accessibilities
df['symmetries'] = symmetries
df['targets'] = targets

# %%
sns.set(font_scale = 1.0)
sns.set_style('white')
plt.rcParams.update({'font.size': 12})
custom_palette = ["#1f77b4", "#ff7f0e"]
sns.set_palette(palette = custom_palette)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

grid = sns.JointGrid(x=df.sort_values('targets')['accessibilities'], y=df.sort_values('targets')['symmetries'], 
                     data=df.sort_values('targets'), marginal_ticks=True)

g = grid.plot_joint(sns.scatterplot, hue='targets', data=df.sort_values('targets'), s=50, alpha=0.3, edgecolor='face')

g.ax_joint.set_ylabel('Accessibility std')
g.ax_joint.set_xlabel('Accessibility mean')
g.ax_joint.tick_params(which='major', direction="in", left=True, bottom=True)
plt.setp(g.ax_joint.get_yticklabels()[-1], visible=False)
plt.setp(g.ax_joint.get_xticklabels()[-1], visible=False)

leg = g.ax_joint.legend(loc="lower right", scatterpoints=1)
for lh in leg.legendHandles: 
    lh.set_alpha(0.3)
    lh.set_sizes([50])
    lh.set_edgecolors('face')

sns.kdeplot(x=df.loc[df['targets']=='meaningless', 'accessibilities'], ax=g.ax_marg_x, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(x=df.loc[df['targets']=='real', 'accessibilities'], ax=g.ax_marg_x, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(y=df.loc[df['targets']=='meaningless', 'symmetries'], ax=g.ax_marg_y, legend=False, bw_method=0.1, alpha=1, linewidth=2)
sns.kdeplot(y=df.loc[df['targets']=='real', 'symmetries'], ax=g.ax_marg_y, legend=False, bw_method=0.1, alpha=1, linewidth=2)

g.ax_marg_x.set_yticks([0.00, 0.03])
g.ax_marg_y.set_xticks([0, 0.03])

g.ax_marg_x.tick_params(which='major', direction="in", left=True)
g.ax_marg_y.tick_params(which='major', direction="in", bottom=True)

g.ax_joint.text(20, 145, "KS:\n" + str(ks2d2s(np.array(df.loc[df['targets']=='real', ['accessibilities', 'symmetries']]), np.array(df.loc[df['targets']=='meaningless', ['accessibilities', 'symmetries']]))))

g.fig.set_size_inches((3.5, 3.5))
g.fig.set_rasterized(True)

g.savefig('access_random.pdf', bbox_inches='tight', dpi=300)
plt.show()
